# %%
# !pip install bertviz
# Out:
# ...
#   Using cached bertviz-1.4.1-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# ...
# Using cached bertviz-1.4.1-py3-none-any.whl (157 kB)
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 8.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    --------------- ------------------------ 5.5/14.6 MB 25.7 MB/s eta 0:00:01
#    -------------------------- ------------- 9.7/14.6 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 27.7 MB/s eta 0:00:00
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
LABEL_TO_ID = {
    "pants-fire": 0,
    "false": 1,
    "barely-true": 2,
    "half-true": 3,
    "mostly-true": 4,
    "true": 5,
}
ID_TO_LABEL = {v: k for k, v in LABEL_TO_ID.items()}
model_dir = 'D:\\univ_subj\\M_An_I\\FNLP\\Proiect-FNLP\\model_weights\\BEST\\best_model'

# %%
with open('D:\\univ_subj\\M_An_I\\FNLP\\Proiect-FNLP\\report\\files\\misclassified_samples.txt', 'r', encoding='utf-8') as f:
    misclassified_samples = f.readlines()

with open('D:\\univ_subj\\M_An_I\\FNLP\\Proiect-FNLP\\report\\files\\correct_samples.txt', 'r', encoding='utf-8') as f:
    correct_samples = f.readlines()

# %%
sentence = correct_samples[3]

# %%
from bertviz import head_view, model_view
from transformers import RobertaTokenizer, RobertaModel
from pathlib import Path

tokenizer = RobertaTokenizer.from_pretrained(Path(str(model_dir)), use_fast=True)
model = RobertaModel.from_pretrained(
    str(model_dir),
    output_attentions=True
)

inputs = tokenizer.encode_plus(sentence, return_tensors='pt')
input_ids = inputs['input_ids']
attention = model(input_ids)[-1]
input_id_list = input_ids[0].tolist() # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at D:\univ_subj\M_An_I\FNLP\Proiect-FNLP\model_weights\BEST\best_model and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
head_view(attention, tokens)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-f39964160f4542cd9f4e23bf547347ee" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
model_view(attention, tokens)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-b98f38a03e3c47c1a6eafc81cfa10e40" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>
